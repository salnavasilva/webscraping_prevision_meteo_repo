# %% [markdown]
# # Web scraping données Météo
#
# Dans ce notebook on extrait les données meteorologiques brutes à partir du site XXXX en utilisant plusieurs packages python tels que beautiful soup.

# %% [markdown]
# ## Importation
# Libraries natives & personalisées

# %%
import requests
import lxml.html as lh
from bs4 import BeautifulSoup

# %% [markdown]
# ## Parametres

# %%
# TODO

# %% [markdown]
# ## Chargement de la page web de choix (source de données)
# Pour ce projet on va prendre comme source data le site web : 'https://www.historique-meteo.net'

# %%
url_meteo = 'https://www.historique-meteo.net'
page = requests.get(url=url_meteo , verify=False)
soupObjet = BeautifulSoup(page.content, 'html')
# Out:
# c:\Users\USNA0501\Anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.historique-meteo.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
print(soupObjet.get_text())
# Out:
# Historique-Météo.net : les archives météo dans le monde entier gratuitement
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Accueil du site
#
#
# Par continents
#
# l'Afriquel'Amérique centralel'Amérique du nordl'Amérique du sudl'Asie centrale et du sudl'Asie du Sud-Estl'Asie orientaleles Caraïbesl'Europela Francele Moyen Orientl'Océanie
#
#
#
#
#
#
#
#
#
#
#
#
#
# Historique météo : archives météo pour le monde entier
# Retrouvez les archives météo complètes (température, précipitations, état du ciel, humidité, vent...) d'une journée ou d'un mois précis partout en France et dans le monde avec notre service gratuit d'historique météo.
#
#
#
#
#
#
#
#
#
#
# Rechercher l'historique météo d'une ville, d'un pays  ou d'une région française
#
#
#
#                   en
#
#
# janvierfévriermarsavrilmaijuinjuilletaoûtseptembreoctobrenovembredécembre
#
#
#
# 2009201020112012201320142015201620172018201920202021202220232024
#
#
#
#
#
#
#
#
# ...
